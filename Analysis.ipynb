# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("Mental_Health.csv")

# %%
# Understanding the data
data.head(5)
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10)
# 0              Facebook                   10.0
# ...

# %%
data.tail()
# Out:
#     User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 495    U496   23    Male                     6.9                  5.0
# 496    U497   43  Female                     5.6                  7.0
# 497    U498   41    Male                     7.7                  5.0
# 498    U499   23    Male                     4.2                  9.0
# 499    U500   43  Female                     5.9                  5.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 495                 7.0                        4.0                       2.0
# 496                 6.0                        5.0                       2.0
# 497                 7.0                        2.0                       2.0
# 498                 7.0                        0.0                       2.0
# 499                 8.0                        3.0                       3.0
#
#     Social_Media_Platform  Happiness_Index(1-10)
# ...

# %%
data.shape
# Out:
# (500, 10)

# %%
data.describe()
# Out:
#               Age  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# count  500.000000              500.000000           500.000000
# mean    32.988000                5.530000             6.304000
# std      9.960637                1.734877             1.529792
# min     16.000000                1.000000             2.000000
# 25%     24.000000                4.300000             5.000000
# 50%     34.000000                5.600000             6.000000
# 75%     41.000000                6.700000             7.000000
# max     49.000000               10.800000            10.000000
#
#        Stress_Level(1-10)  Days_Without_Social_Media  \
# count          500.000000                 500.000000
# mean             6.618000                   3.134000
# std              1.542996                   1.858751
# min              2.000000                   0.000000
# 25%              6.000000                   2.000000
# 50%              7.000000                   3.000000
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Daily_Screen_Time(hrs)',
#        'Sleep_Quality(1-10)', 'Stress_Level(1-10)',
#        'Days_Without_Social_Media', 'Exercise_Frequency(week)',
#        'Social_Media_Platform', 'Happiness_Index(1-10)'],
#       dtype='object')

# %%
data.nunique()
# Out:
# User_ID                      500
# Age                           34
# Gender                         3
# Daily_Screen_Time(hrs)        82
# Sleep_Quality(1-10)            9
# Stress_Level(1-10)             9
# Days_Without_Social_Media      9
# Exercise_Frequency(week)       8
# Social_Media_Platform          6
# Happiness_Index(1-10)          7
# dtype: int64

# %%
data["Social_Media_Platform"].unique()
# Out:
# array(['Facebook', 'LinkedIn', 'YouTube', 'TikTok', 'X (Twitter)',
#        'Instagram'], dtype=object)

# %%
# Cleaning the data

# %%
data.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Daily_Screen_Time(hrs)       0
# Sleep_Quality(1-10)          0
# Stress_Level(1-10)           0
# Days_Without_Social_Media    0
# Exercise_Frequency(week)     0
# Social_Media_Platform        0
# Happiness_Index(1-10)        0
# dtype: int64

# %%
social = data.drop(["User_ID","Exercise_Frequency(week)"] ,axis = 1)

# %%
social.head()
# Out:
#    Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0   44    Male                     3.1                  7.0
# 1   30   Other                     5.1                  7.0
# 2   23   Other                     7.4                  6.0
# 3   36  Female                     5.7                  7.0
# 4   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media Social_Media_Platform  \
# 0                 6.0                        2.0              Facebook
# 1                 8.0                        5.0              LinkedIn
# 2                 7.0                        1.0               YouTube
# 3                 8.0                        1.0                TikTok
# 4                 7.0                        5.0           X (Twitter)
#
#    Happiness_Index(1-10)
# 0                   10.0
# 1                   10.0
# 2                    6.0
# 3                    8.0
# 4                    8.0

# %%
# Realationship Analysis

# %%
correlation = social.select_dtypes(include=['number']).corr()

# %%
sns.heatmap(correlation , annot = True )
# Out:
# <Axes: >

# %%
sns.lineplot(
    data=social,
    x="Age",
    y="Happiness_Index(1-10)",
    marker="o",
    hue="Gender",
    linestyle="-"
)
# Out:
# <Axes: xlabel='Age', ylabel='Happiness_Index(1-10)'>

# %%
sns.lineplot(
    data=social,
    x="Age",
    y="Stress_Level(1-10)",
    marker="o",
    hue="Gender",
    linestyle="-"
)
# Out:
# <Axes: xlabel='Age', ylabel='Stress_Level(1-10)'>

# %%
sns.barplot(
    data=social,
    x="Social_Media_Platform",
    y="Stress_Level(1-10)",
    palette="magma"
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19092\3508972132.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='Social_Media_Platform', ylabel='Stress_Level(1-10)'>

# %%
sns.barplot(data=social,
            x="Social_Media_Platform",
            y="Happiness_Index(1-10)" ,
            hue ="Gender")
# Out:
# <Axes: xlabel='Social_Media_Platform', ylabel='Happiness_Index(1-10)'>

# %%
sns.barplot(
    data=social,
    x="Gender",
    y="Daily_Screen_Time(hrs)",
    palette="viridis"
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19092\1448035887.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='Gender', ylabel='Daily_Screen_Time(hrs)'>

# %%
sns.barplot(
    data=social,
    y="Age",
    x="Happiness_Index(1-10)",
    palette="Blues"
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19092\3540110180.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='Happiness_Index(1-10)', ylabel='Age'>

# %%
sns.barplot(
    data=social,
    y="Age",
    x="Stress_Level(1-10)",
    palette="Blues"
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19092\2124139422.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='Stress_Level(1-10)', ylabel='Age'>
